# %% [markdown]
# # Choosing The Number of Clusters
#
# We look at k-modes cost and the centroid labels with 5, 10, 25, and 50 clusters to evaluate which number of clusters is appropriate for extracting important features of crimes.

# %%
import pandas as pd 
import numpy as np 
import math
from kmodes.kmodes import KModes

# %%
# %config IPCompleter.greedy=True

# %% [markdown]
# # Importing Data
# The dataset should be in the crimesInChicagoData folder and the 'dataset.csv' file.

# %%
data = pd.read_csv("../../../crimesInChicagoData/dataset.csv", error_bad_lines = False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#    Unnamed: 0  IUCR                Primary Type  \
# 0           0  0840                       THEFT
# 1           1  2825               OTHER OFFENSE
# 2           2  1752  OFFENSE INVOLVING CHILDREN
# 3           3  0840                       THEFT
# 4           4  0841                       THEFT
#
#                       Description Location Description  Arrest  Domestic  \
# 0   FINANCIAL ID THEFT: OVER $300            RESIDENCE   False     False
# 1         HARASSMENT BY TELEPHONE            RESIDENCE   False      True
# 2   AGG CRIM SEX ABUSE FAM MEMBER            RESIDENCE   False     False
# 3   FINANCIAL ID THEFT: OVER $300                OTHER   False     False
# 4  FINANCIAL ID THEFT:$300 &UNDER            RESIDENCE   False     False
#
#   District    Year Latitude  Longitude  Month  Day  Hour  Weekday
# 0        4  2004.0        0   0.000000      1    1     0        3
# 1        9  2003.0  41.8172 -87.637328      3    1     0        5
# 2       14  2004.0        0   0.000000      6   20    11        6
# 3       25  2004.0        0   0.000000     12   30    20        3
# 4       22  2003.0  41.6918 -87.635116      5    1     1        3

# %%
data = data.drop(['Unnamed: 0'], axis = 1)

# %%
def filterYear(year):
    df = finalDf[finalDf.Year==year]
    return df

# %%
def makeClusters(data, year, numClusters):
    km = KModes(n_clusters=numClusters, init = "Cao", n_init = 1, verbose=1)
    subsetDf = data.loc[data['Year'] == year].drop(['IUCR', 'Primary Type', 'Year', 'Latitude', 'Longitude'], axis = 1)
    subsetData = subsetDf.values
    fitClusters = km.fit_predict(subsetData)
    clusterCentroidsDf = pd.DataFrame(km.cluster_centroids_)
    clusterCentroidsDf.columns = subsetDf.columns
    
    return fitClusters, clusterCentroidsDf

# %%
def labelsDf(year, num, originalData, clusterInfo):
    df = originalData.loc[originalData['Year'] == year]
    df = df.reset_index()
    clustersDf = pd.DataFrame(clusterInfo)
    clustersDf.columns = ['clusters_'+str(num)]
    combinedDf = pd.concat([df, clustersDf], axis = 1).reset_index()
    combinedDf = combinedDf.drop(['index', 'level_0'], axis = 1)
    return combinedDf

# %%
clusterData = data

# %%
clusterData['District'] = pd.DataFrame(clusterData['District']).applymap(str)

# %%
clusterData2001_5clusters = makeClusters(clusterData, 2001, 5)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 3247429.0

# %%
clusterData2001_5clusters[1]
# Out:
#       Description Location Description Arrest Domestic District Month Day  \
# 0          SIMPLE               STREET  False    False      2.0     1  12
# 1  $500 AND UNDER            RESIDENCE  False    False      8.0     2   1
# 2       OVER $500            APARTMENT  False    False      9.0     3   7
# 3      TO VEHICLE             SIDEWALK  False    False     25.0     7   2
# 4  $500 AND UNDER               STREET  False    False     25.0     3   3
#
#   Hour Weekday
# 0   18       4
# 1   20       3
# 2   21       2
# 3   12       0
# 4   19       5

# %%
clusterData2001_10clusters = makeClusters(clusterData, 2001, 10)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 3072983.0

# %%
clusterData2001_10clusters[1]
# Out:
#       Description            Location Description Arrest Domestic District  \
# 0          SIMPLE                          STREET  False    False      2.0
# 1  $500 AND UNDER                       RESIDENCE  False    False      8.0
# 2       OVER $500                       APARTMENT  False    False      9.0
# 3      TO VEHICLE                        SIDEWALK  False    False     25.0
# 4  $500 AND UNDER                          STREET  False    False     25.0
# 5     TO PROPERTY                           OTHER  False    False     12.0
# 6          SIMPLE                       RESIDENCE  False    False      6.0
# 7       OVER $500                          STREET  False    False     11.0
# 8      AUTOMOBILE  PARKING LOT/GARAGE(NON.RESID.)  False    False      7.0
# 9      TO VEHICLE                          STREET  False    False      8.0
#
#   Month Day Hour Weekday
# 0     1  12   18       4
# 1     2   1   20       3
# 2     3   7   21       2
# 3     7   2   12       0
# 4     3   3   19       5
# 5     6  19   22       1
# 6     3  26   22       0
# 7     2  19   15       0
# 8     5   6   14       6
# 9     8   7   17       1

# %%
clusterData2001_25clusters = makeClusters(clusterData, 2001, 25)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 7051, cost: 2839372.0
# Run 1, iteration: 2/100, moves: 0, cost: 2839372.0

# %%
clusterData2001_25clusters[1]
# Out:
#                       Description            Location Description Arrest  \
# 0                          SIMPLE                          STREET  False
# 1                  $500 AND UNDER                       RESIDENCE  False
# 2                       OVER $500                       APARTMENT  False
# 3                      TO VEHICLE                        SIDEWALK  False
# 4                  $500 AND UNDER                          STREET  False
# 5                     TO PROPERTY                           OTHER  False
# 6                          SIMPLE                       RESIDENCE  False
# 7                       OVER $500                          STREET  False
# 8                      AUTOMOBILE  PARKING LOT/GARAGE(NON.RESID.)  False
# 9                      TO VEHICLE                          STREET  False
# 10                    TO PROPERTY                          STREET  False
# 11                     AUTOMOBILE                          STREET  False
# 12  AGGRAVATED: OTHER DANG WEAPON                          STREET  False
# 13                      OVER $500                       RESIDENCE  False
# 14                         SIMPLE                        SIDEWALK  False
# 15                    TO PROPERTY                       RESIDENCE  False
# 16                         SIMPLE                       APARTMENT  False
# 17                     TO VEHICLE                       RESIDENCE  False
# 18                         SIMPLE                           OTHER  False
# 19                 FORCIBLE ENTRY                       RESIDENCE  False
# 20                         SIMPLE  PARKING LOT/GARAGE(NON.RESID.)  False
# 21                 $500 AND UNDER                        SIDEWALK  False
# 22                 $500 AND UNDER                       APARTMENT  False
# 23                         SIMPLE                       RESIDENCE  False
# 24        HARASSMENT BY TELEPHONE                       RESIDENCE  False
#
#    Domestic District Month Day Hour Weekday
# 0     False      2.0     1  12   18       4
# 1     False      8.0     2   1   20       3
# 2     False      9.0     3   7   21       2
# 3     False     25.0     7   2   12       0
# 4     False     25.0     3   3   19       5
# 5     False     12.0     6  19   22       1
# 6     False      6.0     3  26   22       0
# 7     False     11.0     2  19   15       0
# 8     False      7.0     5   6   14       6
# 9     False      8.0     8   7   17       1
# 10    False      6.0     5   9   20       2
# 11    False      4.0    10  11   22       3
# 12    False     19.0     7  15   21       6
# 13    False     25.0     1   9   14       1
# 14    False      7.0     2  27   19       1
# 15    False      2.0    10   6   17       5
# 16    False     11.0     6   2   20       5
# 17    False      4.0     6  15   19       4
# 18    False      8.0     7  18    0       2
# 19    False      7.0     8  22   12       2
# 20    False     25.0     9  13   16       3
# 21    False      4.0     1  21   17       6
# 22    False      2.0     7  10   15       1
# 23    False      3.0    10  28   12       6
# 24    False     12.0     4   8   18       6

# %%
clusterData2001_50clusters = makeClusters(clusterData, 2001, 50)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 15776, cost: 2646485.0
# Run 1, iteration: 2/100, moves: 0, cost: 2646485.0

# %%
clusterData2001_50clusters[1]
# Out:
#                       Description            Location Description Arrest  \
# 0                          SIMPLE                          STREET  False
# 1                  $500 AND UNDER                       RESIDENCE  False
# 2                       OVER $500                       APARTMENT  False
# 3                      TO VEHICLE                        SIDEWALK  False
# 4                  $500 AND UNDER                          STREET  False
# 5                     TO PROPERTY                           OTHER  False
# 6                          SIMPLE                       RESIDENCE  False
# 7                       OVER $500                          STREET  False
# 8                      AUTOMOBILE  PARKING LOT/GARAGE(NON.RESID.)  False
# 9                      TO VEHICLE                          STREET  False
# 10                    TO PROPERTY                          STREET  False
# 11                     AUTOMOBILE                          STREET  False
# 12  AGGRAVATED: OTHER DANG WEAPON                          STREET  False
# 13                      OVER $500                       RESIDENCE  False
# 14                         SIMPLE                        SIDEWALK  False
# 15                    TO PROPERTY                       RESIDENCE  False
# 16                         SIMPLE                       APARTMENT  False
# 17                     TO VEHICLE                       RESIDENCE  False
# 18                         SIMPLE                           OTHER  False
# 19                 FORCIBLE ENTRY                       RESIDENCE  False
# 20                         SIMPLE  PARKING LOT/GARAGE(NON.RESID.)  False
# 21                 $500 AND UNDER                        SIDEWALK  False
# 22                 $500 AND UNDER                       APARTMENT  False
# 23                         SIMPLE                       RESIDENCE  False
# 24        HARASSMENT BY TELEPHONE                       RESIDENCE  False
# 25                    TO PROPERTY                       APARTMENT  False
# 26                 $500 AND UNDER                           OTHER  False
# 27                 $500 AND UNDER  PARKING LOT/GARAGE(NON.RESID.)  False
# 28                         SIMPLE                          STREET   True
# 29                     TO VEHICLE  PARKING LOT/GARAGE(NON.RESID.)  False
# 30                 $500 AND UNDER                           ALLEY  False
# 31                         SIMPLE                          STREET  False
# 32                 FORCIBLE ENTRY                       APARTMENT  False
# 33                         SIMPLE                          STREET  False
# 34                    TO PROPERTY                        SIDEWALK  False
# 35                      OVER $500                           OTHER  False
# 36                         SIMPLE                          STREET  False
# 37                      OVER $500                        SIDEWALK  False
# 38                         SIMPLE                          STREET  False
# 39                         SIMPLE                          STREET  False
# 40                 FORCIBLE ENTRY                RESIDENCE-GARAGE  False
# 41                 $500 AND UNDER                          STREET  False
# 42                     TO VEHICLE         CHA PARKING LOT/GROUNDS  False
# 43                     AUTOMOBILE                          STREET  False
# 44                         SIMPLE                          STREET  False
# 45                      OVER $500  PARKING LOT/GARAGE(NON.RESID.)  False
# 46                 $500 AND UNDER                          STREET  False
# 47                 $500 AND UNDER                          STREET  False
# 48                     AUTOMOBILE                           OTHER  False
# 49                 ARMED: HANDGUN                        SIDEWALK  False
#
#    Domestic District Month Day Hour Weekday
# 0     False      2.0     1  12   18       4
# 1     False      8.0     2   1   20       3
# 2     False      9.0     3   7   21       2
# 3     False     25.0     7   2   12       0
# 4     False     25.0     3   3   19       5
# 5     False     12.0     6  19   22       1
# 6     False      6.0     3  26   22       0
# 7     False     11.0     2  19   15       0
# 8     False      7.0     5   6   14       6
# 9     False      8.0     8   7   17       1
# 10    False      6.0     5   9   20       2
# 11    False      4.0    10  11   22       3
# 12    False     19.0     7  15   21       6
# 13    False     25.0     1   9   14       1
# 14    False      7.0     2  27   19       1
# 15    False      2.0    10   6   17       5
# 16    False     11.0     6   2   20       5
# 17    False      4.0     6  15   19       4
# 18    False      8.0     7  18    0       2
# 19    False      7.0     8  22   12       2
# 20    False     25.0     9  13   16       3
# 21    False      4.0     1  21   17       6
# 22    False      2.0     7  10   15       1
# 23    False      3.0    10  28   12       6
# 24    False     12.0     4   8   18       6
# 25    False      3.0     1   1   19       0
# 26    False      7.0    10   5   16       4
# 27    False     18.0     8  27   18       0
# 28    False      8.0     2  10   23       5
# 29    False      6.0     1  20   15       5
# 30    False     19.0     9  12   22       2
# 31    False     25.0     2  21   12       2
# 32    False     14.0     2  16   22       4
# 33    False      8.0     3  22   21       3
# 34    False     18.0     3  23    0       4
# 35    False      2.0     8  23   10       3
# 36    False      7.0    10   1   20       0
# 37    False     12.0     9  15   13       5
# 38    False     11.0     5   8   22       1
# 39    False      6.0     7   7   14       5
# 40    False      9.0     1  25   23       3
# 41    False      8.0     1   8   14       0
# 42    False      2.0     3  11   13       6
# 43    False      3.0     2  17    0       5
# 44    False      9.0     6  10   19       6
# 45    False     19.0    11   2   17       4
# 46    False      2.0     2   4   22       6
# 47    False     11.0     1  17   11       2
# 48    False      9.0    12   3   17       0
# 49    False     14.0     6   7   18       3

# %%
# Out:
# 0
