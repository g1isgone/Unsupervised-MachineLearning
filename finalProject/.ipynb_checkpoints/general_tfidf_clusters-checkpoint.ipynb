# %% [markdown]
# http://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html

# %%
import numpy as np  
import pandas as pd 
import math

# %%
# Tells matplotlib to display images inline instead of a new window
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
datasetFilePath = "../../crimesInChicagoData/Unsupervised-MachineLearning/finalProject/year2001_50clusters.csv"
centroidsInfoFilePath = "../../crimesInChicagoData/Unsupervised-MachineLearning/finalProject/year2001_50clusterCentroids.csv"
clusterColumnName = 'clusters_50'
numClusters = 50

# %%
clusters = pd.read_csv(datasetFilePath)

# %%
clusters.head()
# Out:
#    Unnamed: 0  index  IUCR                Primary Type  \
# 0           0      6  0266         CRIM SEXUAL ASSAULT
# 1           1     17  1753  OFFENSE INVOLVING CHILDREN
# 2           2     18  0840                       THEFT
# 3           3     20  1754  OFFENSE INVOLVING CHILDREN
# 4           4     25  1563                 SEX OFFENSE
#
#                       Description Location Description  Arrest  Domestic  \
# 0                       PREDATORY            RESIDENCE    True      True
# 1   SEX ASSLT OF CHILD BY FAM MBR            RESIDENCE    True     False
# 2   FINANCIAL ID THEFT: OVER $300                OTHER   False     False
# 3  AGG SEX ASSLT OF CHILD FAM MBR            RESIDENCE    True     False
# 4           CRIMINAL SEXUAL ABUSE            RESIDENCE   False     False
#
#    District    Year  Month  Day  Hour  index.1  clusters_50
# 0       5.0  2001.0      1    1    11        0           10
# 1       8.0  2001.0      1    1     0        1            4
# 2       9.0  2001.0      1    1     0        2           26
# 3       7.0  2001.0      6   16     8        3           42
# 4      15.0  2001.0      6    1     8        4            7

# %%
clusters = clusters.drop(['Unnamed: 0', 'index'], axis =1 )

# %%
clusters
# Out:
#         IUCR                Primary Type                     Description  \
# 0       0266         CRIM SEXUAL ASSAULT                       PREDATORY
# 1       1753  OFFENSE INVOLVING CHILDREN   SEX ASSLT OF CHILD BY FAM MBR
# 2       0840                       THEFT   FINANCIAL ID THEFT: OVER $300
# 3       1754  OFFENSE INVOLVING CHILDREN  AGG SEX ASSLT OF CHILD FAM MBR
# 4       1563                 SEX OFFENSE           CRIMINAL SEXUAL ABUSE
# 5       0840                       THEFT   FINANCIAL ID THEFT: OVER $300
# 6       0840                       THEFT   FINANCIAL ID THEFT: OVER $300
# 7       0842                       THEFT         AGG: FINANCIAL ID THEFT
# 8       1752  OFFENSE INVOLVING CHILDREN   AGG CRIM SEX ABUSE FAM MEMBER
# 9       0842                       THEFT         AGG: FINANCIAL ID THEFT
# 10      0265         CRIM SEXUAL ASSAULT               AGGRAVATED: OTHER
# 11      0840                       THEFT   FINANCIAL ID THEFT: OVER $300
# 12      1150          DECEPTIVE PRACTICE               CREDIT CARD FRAUD
# 13      0840                       THEFT   FINANCIAL ID THEFT: OVER $300
# 14      0840                       THEFT   FINANCIAL ID THEFT: OVER $300
# 15      0840                       THEFT   FINANCIAL ID THEFT: OVER $300
# 16      0840                       THEFT   FINANCIAL ID THEFT: OVER $300
# 17      2825               OTHER OFFENSE         HARASSMENT BY TELEPHONE
# 18      1753  OFFENSE INVOLVING CHILDREN   SEX ASSLT OF CHILD BY FAM MBR
# 19      1130          DECEPTIVE PRACTICE        FRAUD OR CONFIDENCE GAME
# 20      0840                       THEFT   FINANCIAL ID THEFT: OVER $300
# 21      1150          DECEPTIVE PRACTICE               CREDIT CARD FRAUD
# 22      0840                       THEFT   FINANCIAL ID THEFT: OVER $300
# 23      0840                       THEFT   FINANCIAL ID THEFT: OVER $300
# 24      0841                       THEFT  FINANCIAL ID THEFT:$300 &UNDER
# 25      0840                       THEFT   FINANCIAL ID THEFT: OVER $300
# 26      0840                       THEFT   FINANCIAL ID THEFT: OVER $300
# 27      0840                       THEFT   FINANCIAL ID THEFT: OVER $300
# 28      1140          DECEPTIVE PRACTICE                    EMBEZZLEMENT
# 29      0841                       THEFT  FINANCIAL ID THEFT:$300 &UNDER
# ...      ...                         ...                             ...
# 568487  0840                       THEFT   FINANCIAL ID THEFT: OVER $300
#
# 27          8    1    12       27            1
# 28          1    1    12       28            5
# 29          1    1     9       29           30
# ...       ...  ...   ...      ...          ...
# 568487     12   28     0   568487            1
# 568488     12    1     0   568488            1
# 568489     12    1     0   568489            1
# 568490      6   18    20   568490           36
# 568491      5   20    23   568491            0
# 568492      6    1     8   568492            1
# 568493      1    1    23   568493            0
# 568494      4   13     0   568494           35
# 568495      1   26    12   568495           42
# 568496      1    9    14   568496           24
# 568497      2    8    12   568497           12
# 568498      3   13    10   568498           37
# 568499      4   12    23   568499            6
# 568500      5   19    23   568500           40
# 568501      7   15     4   568501           44
# 568502      7   15     4   568502            6
# 568503      9    1    16   568503           16
# 568504     11    6    11   568504            6
# 568505     11    9    14   568505           13
# 568506     12   16    19   568506           36
# 568507     12   23    21   568507           26
# 568508      3   10    20   568508            4
# 568509      5   15    12   568509            0
# 568510      1    1     0   568510            7
# 568511      1    1     0   568511           26
# 568512      1    1     0   568512           26
# 568513      3   31     0   568513            1
# 568514      8   15    12   568514            0
# 568515      4    1     9   568515           30
# 568516      6    4     0   568516           13
#
# [568517 rows x 13 columns]

# %%
clusters.shape
# Out:
# (568517, 13)

# %% [markdown]
# # Training and Test Data Subset

# %%
import random 
random.seed(1)

# %%
def subsetData(df, percentage): 
    msk = np.random.rand(len(df)) < percentage
    train = df[msk]
    test = df[~msk]
    return train, test

# %%
splitData = subsetData(clusters, 0.7)

# %%
train = splitData[0]

# %%
test = splitData[1]

# %%
len(train)
# Out:
# 397997

# %%
len(test)
# Out:
# 170520

# %% [markdown]
# # Choosing Training & Test data

# %%
def chooseData(columnName, df):
    selectedData = df[columnName].values
    return selectedData

# %%
train_x_description = chooseData('Description', train)

# %%
train_y_description = chooseData(clusterColumnName, train)

# %%
test_x_description = chooseData('Description', test)

# %%
test_y_description = chooseData(clusterColumnName, test)

# %% [markdown]
# # Tokenizing text with scikit-learn

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
def tokenizeText(train_x, test_x):
    count_vect = CountVectorizer()
    train_counts = count_vect.fit_transform(train_x)
    tfidf_transformer = TfidfTransformer()
    train_x_tfidf = tfidf_transformer.fit_transform(train_counts)
    test_counts = count_vect.transform(test_x)
    test_x_tfidf = tfidf_transformer.transform(test_counts)
    
    return count_vect, train_counts, tfidf_transformer, train_x_tfidf, test_counts, test_x_tfidf

# %%
tokenizeInfo = tokenizeText(train_x_description, test_x_description)

# %%
count_vect_description = tokenizeInfo[0]
train_counts_description = tokenizeInfo[1]
tfidf_transformer_description = tokenizeInfo[2]
train_x_tfidf_description = tokenizeInfo[3]
test_counts_description = tokenizeInfo[4]
test_x_tfidf_description = tokenizeInfo[5]

# %% [markdown]
# # Training a Classifier

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
def trainClassifier(train_x_tfidf, train_y, test_x_tfidf):
    clf = MultinomialNB().fit(train_x_tfidf, train_y)
    predicted = clf.predict(test_x_tfidf)
    #for test_row, cluster in zip(test_x, predicted): 
    #print('%r => %s' % (test_row, train_y[cluster]))
    
    return clf, predicted

# %%
classifierInfo = trainClassifier(train_x_tfidf_description, train_y_description, test_x_tfidf_description)

# %%
clf_description = classifierInfo[0]
predicted_description = classifierInfo[1]

# %%
clf_description
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
predicted_description
# Out:
# array([ 1,  1,  1, ...,  7, 31, 13])

# %% [markdown]
# # Evaluation of the Performance on the Test Set

# %%
def evaluateTestPerformance(predicted, test_y):
    print("The test has an accuracy of: ")
    print((np.mean(predicted == test_y)))

# %%
evaluateTestPerformance(predicted_description, test_y_description)
# Out:
# The test has an accuracy of:
# 0.495654468684

# %% [markdown]
# # SVM Machine to Improve Performance on Test Set

# %%
from sklearn.linear_model import SGDClassifier

# %%
def improveWithSVM(train_x_tfidf, train_y, test_x_tfidf): 
    svm_clf = SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=42,max_iter=5, tol=None)
    print(svm_clf.fit(train_x_tfidf, train_y)) 
    print(svm_clf.coef_)
    svm_predicted = svm_clf.predict(test_x_tfidf)
    
    return svm_clf, svm_predicted

# %%
svmInfo = improveWithSVM(train_x_tfidf_description, train_y_description, test_x_tfidf_description)
# Out:
# SGDClassifier(alpha=0.001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=5, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=42, shuffle=True,
#        tol=None, verbose=0, warm_start=False)
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00  -3.02525739e-04]
#  [  5.16897004e-18   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#    -2.55898557e-04  -3.02525739e-04]
#  [  2.61693371e-04   5.64959183e-04   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  ...,
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]]

# %%
svm_clf_description = svmInfo[0]
svm_predicted_description = svmInfo[1]

# %%
evaluateTestPerformance(svm_predicted, test_y_description)
# Out:
# The test has an accuracy of:
# 0.479937837204

# %%
from sklearn import metrics

# %%
def createTargetNames(numClusters):
    clusterNames = []
    for i in range(numClusters):
        clusterName = "cluster_"+str(i)
        clusterNames.append(clusterName)
    return clusterNames

# %%
targetNames = createTargetNames(numClusters)
targetNames
# Out:
# ['cluster_0',
#  'cluster_1',
#  'cluster_2',
#  'cluster_3',
#  'cluster_4',
#  'cluster_5',
#  'cluster_6',
#  'cluster_7',
#  'cluster_8',
#  'cluster_9',
#  'cluster_10',
#  'cluster_11',
#  'cluster_12',
#  'cluster_13',
#  'cluster_14',
#  'cluster_15',
#  'cluster_16',
#  'cluster_17',
#  'cluster_18',
#  'cluster_19',
#  'cluster_20',
#  'cluster_21',
#  'cluster_22',
#  'cluster_23',
#  'cluster_24',
#  'cluster_25',
#  'cluster_26',
#  'cluster_27',
#  'cluster_28',
#  'cluster_29',
#  'cluster_30',
#  'cluster_31',
#  'cluster_32',
#  'cluster_33',
#  'cluster_34',
#  'cluster_35',
#  'cluster_36',
#  'cluster_37',
#  'cluster_38',
#  'cluster_39',
#  'cluster_40',
#  'cluster_41',
#  'cluster_42',
#  'cluster_43',
#  'cluster_44',
#  'cluster_45',
#  'cluster_46',
#  'cluster_47',
#  'cluster_48',
#  'cluster_49']

# %%
def showMetrics(test_y, svm_predicted, targetNames):
    print(metrics.classification_report(test_y, svm_predicted, target_names = targetNames))
    print(metrics.confusion_matrix(test_y, svm_predicted))

# %%
showMetrics(test_y_description, svm_predicted_description, targetNames)
# Out:
#              precision    recall  f1-score   support
#
#   cluster_0       0.15      0.79      0.25      7180
#   cluster_1       0.29      0.83      0.43      8315
#   cluster_2       0.05      0.02      0.02      4819
#   cluster_3       0.06      0.01      0.02      7266
#   cluster_4       0.67      0.77      0.72      5377
#   cluster_5       0.11      0.02      0.03      4717
#   cluster_6       0.59      0.82      0.68      5073
#   cluster_7       0.93      0.75      0.83      4865
#   cluster_8       0.69      0.89      0.78      7484
#   cluster_9       0.76      0.78      0.77      2631
#  cluster_10       0.76      0.83      0.79      7959
#  cluster_11       0.02      0.00      0.01      1010
#  cluster_12       0.00      0.00      0.00      3842
#  cluster_13       0.66      0.88      0.75      5269
#  cluster_14       0.03      0.03      0.03      3149
#  cluster_15       0.74      0.94      0.83      7759
#  cluster_16       0.07      0.01      0.01      2294
#  cluster_17       0.07      0.00      0.01      2050
#  cluster_18       0.96      0.96      0.96     11439
#  cluster_19       0.02      0.02      0.02      1381
#  cluster_20       0.81      0.78      0.79      2343
#  cluster_21       0.00      0.00      0.00      1412
#  cluster_22       0.80      0.58      0.67      1658
#  cluster_23       0.00      0.00      0.00      4099
#  cluster_24       0.00      0.00      0.00      2161
#  cluster_25       0.06      0.01      0.02      1527
#  cluster_26       0.00      0.00      0.00      5338
#  cluster_27       0.00      0.00      0.00      2309
#  cluster_28       0.23      0.01      0.01       987
#  cluster_29       0.10      0.00      0.00      1656
#  cluster_30       0.69      0.84      0.76      3794
#  cluster_31       0.00      0.00      0.00      1338
#  cluster_32       0.66      0.66      0.66      4195
#  cluster_33       0.00      0.00      0.00      1488
#  cluster_34       0.00      0.00      0.00      1382
#  cluster_35       0.69      0.79      0.74       962
#  cluster_36       0.00      0.00      0.00      2150
#  cluster_37       0.51      0.97      0.67      5220
#  cluster_38       0.00      0.00      0.00      1632
#  cluster_39       0.00      0.00      0.00       762
#  cluster_40       0.00      0.00      0.00      4332
#  cluster_41       0.50      0.80      0.62      3808
#  cluster_42       0.02      0.01      0.01      1546
#  cluster_43       0.00      0.00      0.00      1323
#  cluster_44       0.00      0.00      0.00      1285
#  cluster_45       0.07      0.01      0.02      2513
#  cluster_46       0.27      0.87      0.41      1147
#  cluster_47       0.03      0.00      0.00      2632
#  cluster_48       0.00      0.00      0.00       760
#  cluster_49       0.00      0.00      0.00       882
#
# avg / total       0.38      0.48      0.40    170520
#
# [[5653  126  150 ...,   27    0    0]
#  [  39 6918  106 ...,   28    0    0]
#  [3528   37   78 ...,    7    0    0]
#  ...,
#  [2406    2    8 ...,    5    0    0]
#  [ 688    1    7 ...,    0    0    0]
#  [   7  770   20 ...,    0    0    0]]
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# # Grid Search Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
def gridSearchParamTune(svm_clf, train_counts, train_y):
    parameters = {'alpha': (1e-2, 1e-3)}
    gs_clf = GridSearchCV(svm_clf, parameters)
    gs_clf = gs_clf.fit(train_counts, train_y)
    print(gs_clf.best_params_)
    print(gs_clf.best_score_)
    return gs_clf

# %%
gs_clf_description = gridSearchParamTune(svm_clf_description, train_counts_description, train_y_description)
# Out:
# {'alpha': 0.001}
# 0.439460598949

# %% [markdown]
# # Visualizing The Results
# https://buhrmann.github.io/tfidf-analysis.html

# %%
def top_tfidf_feats(row, features, top_n=25):
    ''' Get top n tfidf values in row and return them with their corresponding feature names.'''
    topn_ids = np.argsort(row)[::-1][:top_n]
    top_feats = [(features[i], row[i]) for i in topn_ids]
    df = pd.DataFrame(top_feats)
    df.columns = ['feature', 'tfidf']
    return df

# %%
def top_feats_in_doc(Xtr, features, row_id, top_n=25):
    ''' Top tfidf features in specific document (matrix row) '''
    row = np.squeeze(Xtr[row_id].toarray())
    return top_tfidf_feats(row, features, top_n)

# %%
def top_feats_by_class(Xtr, y, features, min_tfidf=0.1, top_n=10):
    ''' Return a list of dfs, where each df holds top_n features and their mean tfidf value
        calculated across documents with the same class label. '''
    dfs = []
    labels = np.unique(y)
    for label in labels:
        ids = np.where(y==label)
        feats_df = top_mean_feats(Xtr, features, ids, min_tfidf=min_tfidf, top_n=top_n)
        feats_df.label = label
        dfs.append(feats_df)
    return dfs

# %%
def top_mean_feats(Xtr, features, grp_ids=None, min_tfidf=0.1, top_n=25):
    ''' Return the top n features that on average are most important amongst documents in rows
        indentified by indices in grp_ids. '''
    if grp_ids:
        D = Xtr[grp_ids].toarray()
    else:
        D = Xtr.toarray()

    D[D < min_tfidf] = 0
    tfidf_means = np.mean(D, axis=0)
    return top_tfidf_feats(tfidf_means, features, top_n)

# %%
def plot_tfidf_classfeats_h(dfs):
    ''' Plot the data frames returned by the function plot_tfidf_classfeats(). '''
    fig = plt.figure(figsize=(12, 9), facecolor="w")
    x = np.arange(len(dfs[0]))
    for i, df in enumerate(dfs):
        ax = fig.add_subplot(1, len(dfs), i+1)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.set_frame_on(False)
        ax.get_xaxis().tick_bottom()
        ax.get_yaxis().tick_left()
        ax.set_xlabel("Mean Tf-Idf Score", labelpad=16, fontsize=14)
        ax.set_title("label = " + str(df.label), fontsize=16)
        ax.ticklabel_format(axis='x', style='sci', scilimits=(-2,2))
        ax.barh(x, df.tfidf, align='center', color='#3F5D7D')
        ax.set_yticks(x)
        ax.set_ylim([-1, x[-1]+1])
        yticks = ax.set_yticklabels(df.feature)
        plt.subplots_adjust(bottom=0.09, right= 10, left=0.15, top=0.8, wspace=0.52)
    plt.show()

# %%
def visualizeTfidf(count_vect, train_x_tfidf, train_y):
    features=count_vect.get_feature_names()
    dfs = top_feats_by_class(train_x_tfidf, train_y, features)
    plot_tfidf_classfeats_h(dfs)

# %%
pd.set_option('display.max_columns', None)

# %%
visualizeTfidf(count_vect_description, train_x_tfidf_description, train_y_description)

# %%
centroidsLabels = pd.read_csv(centroidsInfoFilePath)

# %%
centroidsLabels
# Out:
#     Unnamed: 0  index  IUCR         Primary Type  \
# 0            0     41  0486              BATTERY
# 1            1     48  0610             BURGLARY
# 2            2      5  0560              ASSAULT
# 3            3    517  1320      CRIMINAL DAMAGE
# 4            4     74  0460              BATTERY
# 5            5    119  0910  MOTOR VEHICLE THEFT
# 6            6     86  0430              BATTERY
# 7            7   2583  0486              BATTERY
# 8            8    162  0860                THEFT
# 9            9    176  1811            NARCOTICS
# 10          10     21  0820                THEFT
# 11          11     88  0810                THEFT
# 12          12     28  0820                THEFT
# 13          13     55  0610             BURGLARY
# 14          14      2  2825        OTHER OFFENSE
# 15          15     91  0486              BATTERY
# 16          16    169  0460              BATTERY
# 17          17     11  0880                THEFT
# 18          18    189  2027            NARCOTICS
# 19          19   2060  0910  MOTOR VEHICLE THEFT
# 20          20    182  0460              BATTERY
# 21          21    551  0910  MOTOR VEHICLE THEFT
# 22          22      3  0820                THEFT
# 23          23     43  1330    CRIMINAL TRESPASS
# 24          24    187  2024            NARCOTICS
# 25          25     95  5001        OTHER OFFENSE
# 26          26    548  0910  MOTOR VEHICLE THEFT
# 27          27   7006  0486              BATTERY
# 28          28   1231  0486              BATTERY
# 29          29     46  0460              BATTERY
# 30          30   2539  0460              BATTERY
# 31          31    316  0486              BATTERY
# 32          32    322  051A              ASSAULT
# 33          33    523  4387        OTHER OFFENSE
# 34          34    178  1506         PROSTITUTION
# 35          35   2327  0620             BURGLARY
# 36          36      8  0890                THEFT
# 37          37    571  1320      CRIMINAL DAMAGE
# 38          38    279  1310      CRIMINAL DAMAGE
# 39          39   2131  1310      CRIMINAL DAMAGE
# 40          40     59  1310      CRIMINAL DAMAGE
# 41          41     60  0820                THEFT
# 42          42    177  0820                THEFT
# 43          43     61  0820                THEFT
# 44          44      0  1121   DECEPTIVE PRACTICE
# 45          45    790  0810                THEFT
# 46          46     57  2820        OTHER OFFENSE
# 47          47   1706  0460              BATTERY
# 48          48    163  0820                THEFT
# 49          49   1847  0910  MOTOR VEHICLE THEFT
#
#                        Description Location Description  Arrest  Domestic  \
# 0          DOMESTIC BATTERY SIMPLE            RESIDENCE    True     False
# 1                   FORCIBLE ENTRY            RESIDENCE    True     False
# 2                           SIMPLE               STREET   False     False
# 3                       TO VEHICLE               STREET    True     False
# 4                           SIMPLE             SIDEWALK   False     False
# 5                       AUTOMOBILE               STREET   False     False
# 6    AGGRAVATED: OTHER DANG WEAPON               STREET   False     False
# 7          DOMESTIC BATTERY SIMPLE             SIDEWALK    True     False
# 8                     RETAIL THEFT   GROCERY FOOD STORE    True     False
# 9     POSS: CANNABIS 30GMS OR LESS               STREET    True     False
# 10                  $500 AND UNDER               STREET   False     False
# 11                       OVER $500               STREET   False     False
# 12                  $500 AND UNDER               STREET   False     False
# 13                  FORCIBLE ENTRY            RESIDENCE   False     False
# 14         HARASSMENT BY TELEPHONE            RESIDENCE   False     False
# 15         DOMESTIC BATTERY SIMPLE            APARTMENT   False      True
# 16                          SIMPLE               STREET   False     False
# 17                 PURSE-SNATCHING               STREET   False     False
# 18                     POSS: CRACK             SIDEWALK    True     False
# 19                      AUTOMOBILE               STREET   False     False
# 20                          SIMPLE               STREET    True     False
# 21                      AUTOMOBILE               STREET   False     False
# 22                  $500 AND UNDER               STREET   False     False
# 23                         TO LAND                OTHER    True     False
# 24             POSS: HEROIN(WHITE)               STREET    True     False
# 25  OTHER CRIME INVOLVING PROPERTY            RESIDENCE   False     False
# 26                      AUTOMOBILE               STREET   False     False
# 27         DOMESTIC BATTERY SIMPLE               STREET   False      True
# 28         DOMESTIC BATTERY SIMPLE            RESIDENCE    True      True
# 29                          SIMPLE            APARTMENT   False     False
# 30                          SIMPLE             SIDEWALK    True     False
# 31         DOMESTIC BATTERY SIMPLE            RESIDENCE   False     False
# 32             AGGRAVATED: HANDGUN            RESIDENCE   False     False
# 33     VIOLATE ORDER OF PROTECTION               STREET   False     False
# 34           SOLICIT ON PUBLIC WAY               STREET    True     False
# 35                  UNLAWFUL ENTRY            APARTMENT   False     False
# 36                   FROM BUILDING            RESIDENCE   False     False
# 37                      TO VEHICLE               STREET   False     False
# 38                     TO PROPERTY            RESIDENCE   False     False
# 39                     TO PROPERTY            APARTMENT   False     False
# 40                     TO PROPERTY                OTHER   False     False
# 41                  $500 AND UNDER               STREET   False     False
# 42                  $500 AND UNDER               STREET   False     False
# 43                  $500 AND UNDER             SIDEWALK   False     False
# 44         COUNTERFEITING DOCUMENT            RESIDENCE   False     False
# 45                       OVER $500               STREET   False     False
# 46                TELEPHONE THREAT            RESIDENCE   False     False
# 47                          SIMPLE               STREET   False     False
# 48                  $500 AND UNDER               STREET   False     False
# 49                      AUTOMOBILE               STREET    True     False
#
#     District    Year  Month  Day  Hour
# 0       18.0  2004.0      6    1    17
# 1        5.0  2004.0      8    8    19
# 2       11.0  2004.0      8   21    21
# 3       16.0  2004.0      7   29    15
# 4       22.0  2004.0      7   16    21
# 5       14.0  2004.0     12    2    23
# 6        9.0  2004.0      5   21    20
# 7        3.0  2004.0      5   26    20
# 8        1.0  2004.0      8    4    12
# 9        7.0  2004.0      1    2    12
# 10       2.0  2004.0      1    3    18
# 11      12.0  2004.0      8    7    14
# 12      17.0  2004.0     10   27    12
# 13      19.0  2004.0      7    6    10
# 14       2.0  2004.0      6   26    19
# 15      11.0  2004.0      8   17    14
# 16      19.0  2004.0      8   16    10
# 17      10.0  2004.0     11   21     5
# 18      11.0  2004.0     10    6    20
# 19      19.0  2004.0      5   25    21
# 20      10.0  2004.0      8   22     0
# 21       8.0  2004.0      1   15    13
# 22      22.0  2004.0      9   15    20
# 23       1.0  2004.0     11   26    21
# 24      11.0  2004.0      6   21    15
# 25       7.0  2004.0     12   12     9
# 26       4.0  2004.0      5    8    22
# 27      11.0  2004.0      7   16    21
# 28       3.0  2004.0     10   30    22
# 29      14.0  2004.0      6   21    17
# 30       8.0  2004.0     10   22    16
# 31       2.0  2004.0      1    3    23
# 32      15.0  2004.0     11    2    14
# 33      19.0  2004.0     11    2    12
# 34      11.0  2004.0     12    8    20
# 35      14.0  2004.0      2   18     9
# 36      18.0  2004.0      6    1    12
# 37       8.0  2004.0      8   24    22
# 38       8.0  2004.0      9   10    18
# 39       6.0  2004.0      8    9     1
# 40      25.0  2004.0      1   25     8
# 41       6.0  2004.0     10   17    14
# 42       5.0  2004.0      8   19     8
# 43       7.0  2004.0      6    3    13
# 44       4.0  2004.0      1    1     0
# 45      14.0  2004.0      9   19    20
# 46       4.0  2004.0      6   24    22
# 47      12.0  2004.0      6   21    20
# 48       4.0  2004.0      7    5    13
# 49      11.0  2004.0      9    2    17
